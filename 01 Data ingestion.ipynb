# %%
from src.DataUpdateModule import DataUpdateModule

from datetime import datetime
from dateutil.relativedelta import relativedelta
import holidays, warnings

# %%
DUM = DataUpdateModule(options_interval_minutes = 5)
nyse_holidays = holidays.NYSE(years = [2022, 2023, 2024, 2025])

# %%
trade_date = datetime(2024, 4, 21)
max_trade_date = datetime(2025, 10, 31)

dfs_stock = dict()
dfs_options = dict()
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    # for day in range(365):
    while trade_date <= max_trade_date:
        # trade_date = datetime(2024, 4, 21) + relativedelta(days = day)
        if (trade_date.weekday() + 1) % 7 in [5] and trade_date not in nyse_holidays:
            print(trade_date)
            a, b = DUM.update_data(trade_date)
            dfs_stock[trade_date] = a
            dfs_options[trade_date] = b
        trade_date += relativedelta(days = 1)
# Out:
# 2024-04-26 00:00:00
# Stock data: 448 rows
# **************

# %%
import winsound
frequency = 440  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)
